# %%
import open3d as o3d
import numpy as np
from copy import deepcopy
from pathlib import Path
from typing import List, Tuple


def load_capture_sequence(
    dir_path: Path,
    num_captures: int = None,
) -> Tuple[List[o3d.geometry.PointCloud], List[np.ndarray]]:
    pcd_files = sorted(dir_path.glob("*.ply"))
    pose_files = sorted(dir_path.glob("*.txt"))

    if num_captures:
        pcd_files = pcd_files[:num_captures]
        pose_files = pose_files[:num_captures]

    pcds = [o3d.io.read_point_cloud(str(pcd_file)) for pcd_file in pcd_files]
    poses = [np.loadtxt(str(pose_file)) for pose_file in pose_files]

    if len(pcds) == 0:
        raise Exception("No point clouds found")
    if len(poses) == 0:
        raise Exception("No poses found")
    assert len(pcds) == len(poses)

    print(f"Loaded {len(pcds)} point clouds and {len(poses)} poses")

    return pcds, poses


def multiway_pt2pl_registration(
    pcds: List[o3d.geometry.PointCloud],
    reg_max_correspondence_fine: float,
    global_optimization_max_correspondence: float,
    reg_max_correspondence_coarse: float = None,
) -> o3d.pipelines.registration.PoseGraph:
    pose_graph = o3d.pipelines.registration.PoseGraph()
    odometry = np.identity(4)
    pose_graph.nodes.append(o3d.pipelines.registration.PoseGraphNode(odometry))
    n_pcds = len(pcds)

    for source_id in range(n_pcds):
        for target_id in range(source_id + 1, n_pcds):
            if reg_max_correspondence_coarse is not None:
                icp_coarse = o3d.pipelines.registration.registration_icp(
                    source=pcds[source_id],
                    target=pcds[target_id],
                    max_correspondence_distance=reg_max_correspondence_coarse,
                    init=np.identity(4),
                )
            transformation_icp = o3d.pipelines.registration.registration_icp(
                source=pcds[source_id],
                target=pcds[target_id],
                max_correspondence_distance=reg_max_correspondence_fine,
                init=icp_coarse.transformation,
                estimation_method=o3d.pipelines.registration.TransformationEstimationPointToPlane(),
            ).transformation

            information_icp = o3d.pipelines.registration.get_information_matrix_from_point_clouds(
                source=pcds[source_id],
                target=pcds[target_id],
                max_correspondence_distance=reg_max_correspondence_fine,
                transformation=transformation_icp,
            )
            if target_id == source_id + 1:  # odometry case
                odometry = np.dot(transformation_icp, odometry)
                pose_graph.nodes.append(
                    o3d.pipelines.registration.PoseGraphNode(np.linalg.inv(odometry))
                )
                pose_graph.edges.append(
                    o3d.pipelines.registration.PoseGraphEdge(
                        source_id, target_id, transformation_icp, information_icp, uncertain=False
                    )
                )
            else:  # loop closure case
                pose_graph.edges.append(
                    o3d.pipelines.registration.PoseGraphEdge(
                        source_id, target_id, transformation_icp, information_icp, uncertain=True
                    )
                )
    option = o3d.pipelines.registration.GlobalOptimizationOption(
        max_correspondence_distance=global_optimization_max_correspondence,
        edge_prune_threshold=0.25,
        reference_node=0,
    )

    o3d.pipelines.registration.global_optimization(
        pose_graph,
        o3d.pipelines.registration.GlobalOptimizationLevenbergMarquardt(),
        o3d.pipelines.registration.GlobalOptimizationConvergenceCriteria(),
        option,
    )

    return pose_graph


def downsampled_multiway_pt2pl_registration(
    pcds: List[o3d.geometry.PointCloud],
    voxel_size: float = 0.002,
    reg_dist_max_corr_coarse: float = 0.004,
    reg_dist_max_corr_fine: float = 0.002,
    global_optimization_max_correspondence: float = 0.002,
    visualize: bool = False,
) -> List[o3d.geometry.PointCloud]:
    down_pcds = []
    for i in range(len(pcds)):
        down_pcds.append(deepcopy(pcds[i]).voxel_down_sample(voxel_size=voxel_size))

    if visualize:
        o3d.visualization.draw_geometries(down_pcds, window_name="downsampled for registration")

    pose_graph = multiway_pt2pl_registration(
        down_pcds,
        reg_dist_max_corr_coarse,
        reg_dist_max_corr_fine,
        global_optimization_max_correspondence,
    )

    for point_id in range(len(pcds)):
        print(pose_graph.nodes[point_id].pose)
        pcds[point_id].transform(pose_graph.nodes[point_id].pose)

    if visualize:
        o3d.visualization.draw_geometries(pcds, window_name="registration")

    return pcds


def merge_pcds(point_clouds: List[o3d.geometry.PointCloud]) -> o3d.geometry.PointCloud:
    points = []
    colors = []
    normals = []

    for pcd in point_clouds:
        points.append(np.asarray(pcd.points))

        if pcd.has_colors():
            colors.append(np.asarray(pcd.colors))

        if pcd.has_normals():
            normals.append(np.asarray(pcd.normals))

    merged_pcd = o3d.geometry.PointCloud()
    merged_pcd.points = o3d.utility.Vector3dVector(np.vstack(points))

    if colors:
        merged_pcd.colors = o3d.utility.Vector3dVector(np.vstack(colors))

    if normals:
        merged_pcd.normals = o3d.utility.Vector3dVector(np.vstack(normals))

    return merged_pcd
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
# dir_path = Path("/home/v/capture/log2")
dir_path = Path("/home/v/capture/env")

# %%
with o3d.utility.VerbosityContextManager(o3d.utility.VerbosityLevel.Debug):
    pcds, tfs = load_capture_sequence(dir_path)

    pcds = [pcd.remove_non_finite_points() for pcd in pcds]
    pcds = [pcd.transform(tf) for pcd, tf in zip(pcds, tfs)]

    marker = o3d.geometry.TriangleMesh.create_coordinate_frame(size=0.1)

    o3d.visualization.draw_geometries(pcds + [marker], window_name="robot coordinate space")

    pcds = [pcd.remove_statistical_outlier(nb_neighbors=20, std_ratio=2.0)[0] for pcd in pcds]

    o3d.visualization.draw_geometries(pcds, window_name="outlier removal")

    for pcd in pcds:
        pcd.estimate_normals()

    voxel_size = 0.01
    pcds = downsampled_multiway_pt2pl_registration(
        pcds,
        voxel_size=voxel_size,
        reg_dist_max_corr_coarse=voxel_size * 2,
        reg_dist_max_corr_fine=voxel_size,
        global_optimization_max_correspondence=voxel_size,
        visualize=True,
    )

    merged_pcd = merge_pcds(pcds).voxel_down_sample(voxel_size=0.005)

    o3d.visualization.draw_geometries([merged_pcd], window_name="merged point cloud")
# Out:
# [Open3D DEBUG] Format auto File /home/v/capture/env/0_2023_09_12__15_21_04_pcd.ply
# [Open3D DEBUG] Read geometry::PointCloud: 3145728 vertices.
# [Open3D DEBUG] Format auto File /home/v/capture/env/10_2023_09_12__15_24_00_pcd.ply
# [Open3D DEBUG] Read geometry::PointCloud: 3145728 vertices.
# [Open3D DEBUG] Format auto File /home/v/capture/env/1_2023_09_12__15_21_21_pcd.ply
# [Open3D DEBUG] Read geometry::PointCloud: 3145728 vertices.
# [Open3D DEBUG] Format auto File /home/v/capture/env/2_2023_09_12__15_21_37_pcd.ply
# [Open3D DEBUG] Read geometry::PointCloud: 3145728 vertices.
# [Open3D DEBUG] Format auto File /home/v/capture/env/3_2023_09_12__15_21_54_pcd.ply
# [Open3D DEBUG] Read geometry::PointCloud: 3145728 vertices.
# [Open3D DEBUG] Format auto File /home/v/capture/env/4_2023_09_12__15_22_13_pcd.ply
# [Open3D DEBUG] Read geometry::PointCloud: 3145728 vertices.
# [Open3D DEBUG] Format auto File /home/v/capture/env/5_2023_09_12__15_22_28_pcd.ply
# [Open3D DEBUG] Read geometry::PointCloud: 3145728 vertices.
# [Open3D DEBUG] Format auto File /home/v/capture/env/6_2023_09_12__15_22_46_pcd.ply
# [Open3D DEBUG] Read geometry::PointCloud: 3145728 vertices.
# [Open3D DEBUG] Format auto File /home/v/capture/env/7_2023_09_12__15_23_03_pcd.ply
# [Open3D DEBUG] Read geometry::PointCloud: 3145728 vertices.
# [Open3D DEBUG] Format auto File /home/v/capture/env/8_2023_09_12__15_23_23_pcd.ply
# [Open3D DEBUG] Read geometry::PointCloud: 3145728 vertices.
# [Open3D DEBUG] Format auto File /home/v/capture/env/9_2023_09_12__15_23_39_pcd.ply
# [Open3D DEBUG] Read geometry::PointCloud: 3145728 vertices.
# Loaded 11 point clouds and 11 poses
# [Open3D DEBUG] [RemoveNonFinitePoints] 2326985 nan points have been removed.
# [Open3D DEBUG] [RemoveNonFinitePoints] 1672238 nan points have been removed.
# [Open3D DEBUG] [RemoveNonFinitePoints] 2298875 nan points have been removed.
# [Open3D DEBUG] [RemoveNonFinitePoints] 2393272 nan points have been removed.
# [Open3D DEBUG] [RemoveNonFinitePoints] 2301349 nan points have been removed.
# [Open3D DEBUG] [RemoveNonFinitePoints] 2380917 nan points have been removed.
# [Open3D DEBUG] [RemoveNonFinitePoints] 2416379 nan points have been removed.
# [Open3D DEBUG] [RemoveNonFinitePoints] 2206246 nan points have been removed.
# [Open3D DEBUG] [RemoveNonFinitePoints] 2038563 nan points have been removed.
# [Open3D DEBUG] [RemoveNonFinitePoints] 1804629 nan points have been removed.
# [Open3D DEBUG] [RemoveNonFinitePoints] 1702828 nan points have been removed.
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.4107, 1.0610, -0.7709) - (5.0025, 13.6560, 3.0183)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.4107, -2.0102, -0.7709) - (5.0025, 13.6560, 3.0183)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.4107, -2.0102, -0.8030) - (5.0611, 13.6560, 3.0183)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.4107, -2.0102, -0.8030) - (8.6286, 13.6560, 3.0183)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.4107, -2.0102, -0.8455) - (13.1335, 13.6560, 3.0183)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.4107, -2.0102, -0.8782) - (13.1350, 13.6560, 3.0183)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.4107, -2.0102, -0.8782) - (13.1350, 13.6560, 3.0183)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.4107, -2.0102, -0.8782) - (13.1350, 13.6560, 3.0183)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.4107, -2.0102, -0.8782) - (13.1350, 13.6560, 3.0183)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.4107, -2.0102, -0.8782) - (13.1350, 13.6560, 3.0183)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.4107, -2.0102, -0.8782) - (13.1350, 13.6560, 3.0183)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.4107, -2.0102, -0.8782) - (13.1350, 13.6560, 3.0183)]
# [Open3D DEBUG] [Visualizer] Point size set to 4.00.
# [Open3D DEBUG] [Visualizer] Point size set to 3.00.
# [Open3D DEBUG] [Visualizer] Point size set to 2.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] Pointcloud down sampled from 818743 points to 784010 points.
# [Open3D DEBUG] Pointcloud down sampled from 1473490 points to 1423525 points.
# [Open3D DEBUG] Pointcloud down sampled from 846853 points to 826992 points.
# [Open3D DEBUG] Pointcloud down sampled from 752456 points to 726283 points.
# [Open3D DEBUG] Pointcloud down sampled from 844379 points to 822532 points.
# [Open3D DEBUG] Pointcloud down sampled from 764811 points to 737495 points.
# [Open3D DEBUG] Pointcloud down sampled from 729349 points to 720330 points.
# [Open3D DEBUG] Pointcloud down sampled from 939482 points to 910862 points.
# [Open3D DEBUG] Pointcloud down sampled from 1107165 points to 1075600 points.
# [Open3D DEBUG] Pointcloud down sampled from 1341099 points to 1288275 points.
# [Open3D DEBUG] Pointcloud down sampled from 1442900 points to 1387051 points.
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, 1.0610, -0.7705) - (3.8619, 7.4328, 3.0183)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0102, -0.7705) - (3.8619, 7.4328, 3.0183)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0102, -0.8030) - (5.0570, 8.1549, 3.0183)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0102, -0.8030) - (8.6286, 8.6408, 3.0183)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0102, -0.8375) - (11.0852, 8.6408, 3.0183)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0102, -0.8634) - (11.0852, 8.6408, 3.0183)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0102, -0.8634) - (11.0852, 8.6408, 3.0183)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0102, -0.8634) - (11.0852, 8.6408, 3.0183)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0102, -0.8634) - (11.0852, 8.6408, 3.0183)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0102, -0.8634) - (11.0852, 8.6408, 3.0183)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0102, -0.8634) - (11.0852, 8.6408, 3.0183)]
# [Open3D DEBUG] [Visualizer] Reset view point.
# [Open3D DEBUG] [Visualizer] Reset view point.
# [Open3D DEBUG] [Visualizer] Point normal rendering ON.
# [Open3D DEBUG] Pointcloud down sampled from 784010 points to 47155 points.
# [Open3D DEBUG] Pointcloud down sampled from 1423525 points to 27601 points.
# [Open3D DEBUG] Pointcloud down sampled from 826992 points to 122966 points.
# [Open3D DEBUG] Pointcloud down sampled from 726283 points to 149274 points.
# [Open3D DEBUG] Pointcloud down sampled from 822532 points to 189841 points.
# [Open3D DEBUG] Pointcloud down sampled from 737495 points to 158943 points.
# [Open3D DEBUG] Pointcloud down sampled from 720330 points to 159956 points.
# [Open3D DEBUG] Pointcloud down sampled from 910862 points to 140062 points.
# [Open3D DEBUG] Pointcloud down sampled from 1075600 points to 110656 points.
# [Open3D DEBUG] Pointcloud down sampled from 1288275 points to 59757 points.
# [Open3D DEBUG] Pointcloud down sampled from 1387051 points to 32516 points.
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, 1.0634, -0.7704) - (3.8619, 7.4328, 3.0180)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0091, -0.7704) - (3.8619, 7.4328, 3.0180)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0091, -0.8018) - (5.0570, 8.1539, 3.0180)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0091, -0.8018) - (8.6271, 8.6408, 3.0180)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0091, -0.8375) - (11.0852, 8.6408, 3.0180)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0091, -0.8634) - (11.0852, 8.6408, 3.0180)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0091, -0.8634) - (11.0852, 8.6408, 3.0180)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0091, -0.8634) - (11.0852, 8.6408, 3.0180)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0091, -0.8634) - (11.0852, 8.6408, 3.0180)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0091, -0.8634) - (11.0852, 8.6408, 3.0180)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0091, -0.8634) - (11.0852, 8.6408, 3.0180)]
# [Open3D DEBUG] [Visualizer] Point size set to 4.00.
# [Open3D DEBUG] [Visualizer] Point size set to 3.00.
# [Open3D DEBUG] [Visualizer] Point size set to 2.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.1529, RMSE 0.0061
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.1557, RMSE 0.0061
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.1577, RMSE 0.0061
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.1590, RMSE 0.0061
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.1600, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.1609, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.1617, RMSE 0.0059
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.1617, RMSE 0.0059
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.1619, RMSE 0.0059
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.1623, RMSE 0.0059
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.1624, RMSE 0.0059
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.1623, RMSE 0.0059
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.1625, RMSE 0.0059
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.1627, RMSE 0.0059
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.1631, RMSE 0.0059
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.1632, RMSE 0.0059
# [Open3D DEBUG] ICP Iteration #16: Fitness 0.1633, RMSE 0.0059
# [Open3D DEBUG] ICP Iteration #17: Fitness 0.1635, RMSE 0.0059
# [Open3D DEBUG] ICP Iteration #18: Fitness 0.1636, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #19: Fitness 0.1636, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #20: Fitness 0.1637, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #21: Fitness 0.1636, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #22: Fitness 0.1636, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #23: Fitness 0.1637, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #24: Fitness 0.1637, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.2770, RMSE 0.0106
# [Open3D DEBUG] Residual : 7.15e-05 (# of elements : 13061)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.3131, RMSE 0.0096
# [Open3D DEBUG] Residual : 5.25e-05 (# of elements : 14765)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.3316, RMSE 0.0090
# [Open3D DEBUG] Residual : 4.59e-05 (# of elements : 15636)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.3380, RMSE 0.0088
# [Open3D DEBUG] Residual : 4.13e-05 (# of elements : 15939)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.3417, RMSE 0.0086
# [Open3D DEBUG] Residual : 3.92e-05 (# of elements : 16113)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.3464, RMSE 0.0084
# [Open3D DEBUG] Residual : 3.77e-05 (# of elements : 16334)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.3518, RMSE 0.0085
# [Open3D DEBUG] Residual : 3.67e-05 (# of elements : 16589)
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.3593, RMSE 0.0085
# [Open3D DEBUG] Residual : 3.73e-05 (# of elements : 16942)
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.3864, RMSE 0.0091
# [Open3D DEBUG] Residual : 4.77e-05 (# of elements : 18220)
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.5691, RMSE 0.0103
# [Open3D DEBUG] Residual : 7.67e-05 (# of elements : 26837)
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.5847, RMSE 0.0071
# [Open3D DEBUG] Residual : 2.37e-05 (# of elements : 27572)
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.5856, RMSE 0.0068
# [Open3D DEBUG] Residual : 2.17e-05 (# of elements : 27615)
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.5864, RMSE 0.0069
# [Open3D DEBUG] Residual : 2.15e-05 (# of elements : 27654)
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.5867, RMSE 0.0069
# [Open3D DEBUG] Residual : 2.15e-05 (# of elements : 27668)
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.5870, RMSE 0.0069
# [Open3D DEBUG] Residual : 2.15e-05 (# of elements : 27681)
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.5870, RMSE 0.0069
# [Open3D DEBUG] Residual : 2.15e-05 (# of elements : 27680)
# [Open3D DEBUG] ICP Iteration #16: Fitness 0.5870, RMSE 0.0069
# [Open3D DEBUG] Residual : 2.15e-05 (# of elements : 27678)
# [Open3D DEBUG] ICP Iteration #17: Fitness 0.5869, RMSE 0.0069
# [Open3D DEBUG] Residual : 2.15e-05 (# of elements : 27676)
# [Open3D DEBUG] ICP Iteration #18: Fitness 0.5870, RMSE 0.0069
# [Open3D DEBUG] Residual : 2.15e-05 (# of elements : 27679)
# [Open3D DEBUG] ICP Iteration #19: Fitness 0.5871, RMSE 0.0069
# [Open3D DEBUG] Residual : 2.15e-05 (# of elements : 27683)
# [Open3D DEBUG] ICP Iteration #20: Fitness 0.5871, RMSE 0.0069
# [Open3D DEBUG] Residual : 2.16e-05 (# of elements : 27686)
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0645, RMSE 0.0062
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.0675, RMSE 0.0061
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.0707, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.0723, RMSE 0.0058
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.0731, RMSE 0.0057
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.0734, RMSE 0.0056
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.0738, RMSE 0.0056
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.0743, RMSE 0.0056
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.0749, RMSE 0.0056
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.0755, RMSE 0.0056
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.0760, RMSE 0.0056
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.0767, RMSE 0.0055
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.0772, RMSE 0.0055
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.0778, RMSE 0.0055
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.0779, RMSE 0.0055
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.0781, RMSE 0.0055
# [Open3D DEBUG] ICP Iteration #16: Fitness 0.0783, RMSE 0.0055
# [Open3D DEBUG] ICP Iteration #17: Fitness 0.0787, RMSE 0.0055
# [Open3D DEBUG] ICP Iteration #18: Fitness 0.0790, RMSE 0.0055
# [Open3D DEBUG] ICP Iteration #19: Fitness 0.0791, RMSE 0.0055
# [Open3D DEBUG] ICP Iteration #20: Fitness 0.0791, RMSE 0.0055
# [Open3D DEBUG] ICP Iteration #21: Fitness 0.0791, RMSE 0.0055
# [Open3D DEBUG] ICP Iteration #22: Fitness 0.0794, RMSE 0.0056
# [Open3D DEBUG] ICP Iteration #23: Fitness 0.0795, RMSE 0.0056
# [Open3D DEBUG] ICP Iteration #24: Fitness 0.0797, RMSE 0.0056
# [Open3D DEBUG] ICP Iteration #25: Fitness 0.0796, RMSE 0.0055
# [Open3D DEBUG] ICP Iteration #26: Fitness 0.0797, RMSE 0.0055
# [Open3D DEBUG] ICP Iteration #27: Fitness 0.0798, RMSE 0.0055
# [Open3D DEBUG] ICP Iteration #28: Fitness 0.0800, RMSE 0.0055
# [Open3D DEBUG] ICP Iteration #29: Fitness 0.0801, RMSE 0.0055
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.1145, RMSE 0.0094
# [Open3D DEBUG] Residual : 4.41e-05 (# of elements : 5398)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.1259, RMSE 0.0100
# [Open3D DEBUG] Residual : 5.38e-05 (# of elements : 5936)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.2703, RMSE 0.0124
# [Open3D DEBUG] Residual : 1.25e-04 (# of elements : 12748)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.3215, RMSE 0.0068
# [Open3D DEBUG] Residual : 2.27e-05 (# of elements : 15158)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.3207, RMSE 0.0064
# [Open3D DEBUG] Residual : 1.60e-05 (# of elements : 15124)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.3209, RMSE 0.0065
# [Open3D DEBUG] Residual : 1.55e-05 (# of elements : 15130)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.3210, RMSE 0.0064
# [Open3D DEBUG] Residual : 1.55e-05 (# of elements : 15139)
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.3211, RMSE 0.0064
# [Open3D DEBUG] Residual : 1.55e-05 (# of elements : 15140)
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.3211, RMSE 0.0064
# [Open3D DEBUG] Residual : 1.55e-05 (# of elements : 15143)
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.3211, RMSE 0.0064
# [Open3D DEBUG] Residual : 1.55e-05 (# of elements : 15143)
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.3212, RMSE 0.0064
# [Open3D DEBUG] Residual : 1.55e-05 (# of elements : 15144)
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0015, RMSE 0.0071
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.0016, RMSE 0.0066
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.0018, RMSE 0.0067
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.0022, RMSE 0.0068
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.0025, RMSE 0.0067
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.0030, RMSE 0.0067
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.0038, RMSE 0.0067
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.0052, RMSE 0.0068
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.0066, RMSE 0.0067
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.0082, RMSE 0.0067
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.0098, RMSE 0.0066
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.0109, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.0119, RMSE 0.0063
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.0124, RMSE 0.0062
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.0127, RMSE 0.0062
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.0131, RMSE 0.0062
# [Open3D DEBUG] ICP Iteration #16: Fitness 0.0131, RMSE 0.0061
# [Open3D DEBUG] ICP Iteration #17: Fitness 0.0131, RMSE 0.0061
# [Open3D DEBUG] ICP Iteration #18: Fitness 0.0131, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #19: Fitness 0.0131, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #20: Fitness 0.0132, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #21: Fitness 0.0134, RMSE 0.0061
# [Open3D DEBUG] ICP Iteration #22: Fitness 0.0135, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #23: Fitness 0.0137, RMSE 0.0061
# [Open3D DEBUG] ICP Iteration #24: Fitness 0.0138, RMSE 0.0061
# [Open3D DEBUG] ICP Iteration #25: Fitness 0.0139, RMSE 0.0061
# [Open3D DEBUG] ICP Iteration #26: Fitness 0.0139, RMSE 0.0061
# [Open3D DEBUG] ICP Iteration #27: Fitness 0.0140, RMSE 0.0061
# [Open3D DEBUG] ICP Iteration #28: Fitness 0.0139, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #29: Fitness 0.0138, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0264, RMSE 0.0113
# [Open3D DEBUG] Residual : 7.63e-05 (# of elements : 1243)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.0317, RMSE 0.0117
# [Open3D DEBUG] Residual : 7.20e-05 (# of elements : 1494)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.0334, RMSE 0.0116
# [Open3D DEBUG] Residual : 7.17e-05 (# of elements : 1573)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.0356, RMSE 0.0120
# [Open3D DEBUG] Residual : 7.31e-05 (# of elements : 1678)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.0372, RMSE 0.0117
# [Open3D DEBUG] Residual : 7.35e-05 (# of elements : 1754)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.0383, RMSE 0.0119
# [Open3D DEBUG] Residual : 7.35e-05 (# of elements : 1807)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.0386, RMSE 0.0117
# [Open3D DEBUG] Residual : 7.19e-05 (# of elements : 1819)
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.0387, RMSE 0.0118
# [Open3D DEBUG] Residual : 7.12e-05 (# of elements : 1825)
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.0386, RMSE 0.0118
# [Open3D DEBUG] Residual : 7.27e-05 (# of elements : 1820)
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.0384, RMSE 0.0117
# [Open3D DEBUG] Residual : 7.30e-05 (# of elements : 1812)
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.0383, RMSE 0.0117
# [Open3D DEBUG] Residual : 7.40e-05 (# of elements : 1807)
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.0382, RMSE 0.0117
# [Open3D DEBUG] Residual : 7.54e-05 (# of elements : 1800)
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.0382, RMSE 0.0118
# [Open3D DEBUG] Residual : 7.55e-05 (# of elements : 1803)
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.0379, RMSE 0.0118
# [Open3D DEBUG] Residual : 7.35e-05 (# of elements : 1789)
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.0376, RMSE 0.0118
# [Open3D DEBUG] Residual : 7.29e-05 (# of elements : 1773)
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.0373, RMSE 0.0117
# [Open3D DEBUG] Residual : 7.21e-05 (# of elements : 1758)
# [Open3D DEBUG] ICP Iteration #16: Fitness 0.0374, RMSE 0.0118
# [Open3D DEBUG] Residual : 7.35e-05 (# of elements : 1764)
# [Open3D DEBUG] ICP Iteration #17: Fitness 0.0372, RMSE 0.0118
# [Open3D DEBUG] Residual : 7.33e-05 (# of elements : 1753)
# [Open3D DEBUG] ICP Iteration #18: Fitness 0.0369, RMSE 0.0118
# [Open3D DEBUG] Residual : 7.17e-05 (# of elements : 1739)
# [Open3D DEBUG] ICP Iteration #19: Fitness 0.0367, RMSE 0.0118
# [Open3D DEBUG] Residual : 7.10e-05 (# of elements : 1729)
# [Open3D DEBUG] ICP Iteration #20: Fitness 0.0364, RMSE 0.0118
# [Open3D DEBUG] Residual : 7.12e-05 (# of elements : 1715)
# [Open3D DEBUG] ICP Iteration #21: Fitness 0.0362, RMSE 0.0117
# [Open3D DEBUG] Residual : 7.17e-05 (# of elements : 1708)
# [Open3D DEBUG] ICP Iteration #22: Fitness 0.0361, RMSE 0.0117
# [Open3D DEBUG] Residual : 7.17e-05 (# of elements : 1703)
# [Open3D DEBUG] ICP Iteration #23: Fitness 0.0360, RMSE 0.0117
# [Open3D DEBUG] Residual : 7.23e-05 (# of elements : 1698)
# [Open3D DEBUG] ICP Iteration #24: Fitness 0.0359, RMSE 0.0118
# [Open3D DEBUG] Residual : 7.13e-05 (# of elements : 1695)
# [Open3D DEBUG] ICP Iteration #25: Fitness 0.0359, RMSE 0.0118
# [Open3D DEBUG] Residual : 7.15e-05 (# of elements : 1695)
# [Open3D DEBUG] ICP Iteration #26: Fitness 0.0359, RMSE 0.0118
# [Open3D DEBUG] Residual : 7.15e-05 (# of elements : 1695)
# [Open3D DEBUG] ICP Iteration #27: Fitness 0.0359, RMSE 0.0118
# [Open3D DEBUG] Residual : 7.17e-05 (# of elements : 1694)
# [Open3D DEBUG] ICP Iteration #28: Fitness 0.0359, RMSE 0.0118
# [Open3D DEBUG] Residual : 7.14e-05 (# of elements : 1691)
# [Open3D DEBUG] ICP Iteration #29: Fitness 0.0358, RMSE 0.0118
# [Open3D DEBUG] Residual : 7.15e-05 (# of elements : 1686)
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.1288, RMSE 0.0055
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.1298, RMSE 0.0041
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.1299, RMSE 0.0035
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.1297, RMSE 0.0033
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.1299, RMSE 0.0033
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.1298, RMSE 0.0033
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.1298, RMSE 0.0033
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.1298, RMSE 0.0033
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.1370, RMSE 0.0046
# [Open3D DEBUG] Residual : 7.51e-06 (# of elements : 3782)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.1370, RMSE 0.0050
# [Open3D DEBUG] Residual : 7.52e-06 (# of elements : 3781)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.1366, RMSE 0.0054
# [Open3D DEBUG] Residual : 7.59e-06 (# of elements : 3769)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.1365, RMSE 0.0055
# [Open3D DEBUG] Residual : 7.79e-06 (# of elements : 3768)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.1360, RMSE 0.0055
# [Open3D DEBUG] Residual : 7.36e-06 (# of elements : 3754)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.1350, RMSE 0.0054
# [Open3D DEBUG] Residual : 6.52e-06 (# of elements : 3727)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.1349, RMSE 0.0055
# [Open3D DEBUG] Residual : 6.14e-06 (# of elements : 3723)
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.1348, RMSE 0.0055
# [Open3D DEBUG] Residual : 6.28e-06 (# of elements : 3720)
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.1350, RMSE 0.0054
# [Open3D DEBUG] Residual : 5.85e-06 (# of elements : 3727)
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.1354, RMSE 0.0053
# [Open3D DEBUG] Residual : 5.85e-06 (# of elements : 3736)
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.1356, RMSE 0.0052
# [Open3D DEBUG] Residual : 5.77e-06 (# of elements : 3743)
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.1362, RMSE 0.0053
# [Open3D DEBUG] Residual : 6.08e-06 (# of elements : 3759)
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.1362, RMSE 0.0053
# [Open3D DEBUG] Residual : 6.02e-06 (# of elements : 3758)
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.1363, RMSE 0.0053
# [Open3D DEBUG] Residual : 5.97e-06 (# of elements : 3761)
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.1363, RMSE 0.0053
# [Open3D DEBUG] Residual : 6.07e-06 (# of elements : 3763)
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.1365, RMSE 0.0053
# [Open3D DEBUG] Residual : 6.06e-06 (# of elements : 3768)
# [Open3D DEBUG] ICP Iteration #16: Fitness 0.1366, RMSE 0.0054
# [Open3D DEBUG] Residual : 6.10e-06 (# of elements : 3770)
# [Open3D DEBUG] ICP Iteration #17: Fitness 0.1366, RMSE 0.0053
# [Open3D DEBUG] Residual : 6.11e-06 (# of elements : 3771)
# [Open3D DEBUG] ICP Iteration #18: Fitness 0.1367, RMSE 0.0054
# [Open3D DEBUG] Residual : 6.12e-06 (# of elements : 3774)
# [Open3D DEBUG] ICP Iteration #19: Fitness 0.1367, RMSE 0.0053
# [Open3D DEBUG] Residual : 6.13e-06 (# of elements : 3774)
# [Open3D DEBUG] ICP Iteration #20: Fitness 0.1368, RMSE 0.0053
# [Open3D DEBUG] Residual : 6.08e-06 (# of elements : 3775)
# [Open3D DEBUG] ICP Iteration #21: Fitness 0.1368, RMSE 0.0054
# [Open3D DEBUG] Residual : 6.08e-06 (# of elements : 3775)
# [Open3D DEBUG] ICP Iteration #22: Fitness 0.1368, RMSE 0.0053
# [Open3D DEBUG] Residual : 6.09e-06 (# of elements : 3775)
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.3592, RMSE 0.0056
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.3568, RMSE 0.0045
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.3543, RMSE 0.0041
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.3527, RMSE 0.0040
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.3515, RMSE 0.0040
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.3512, RMSE 0.0040
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.3512, RMSE 0.0040
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.4234, RMSE 0.0071
# [Open3D DEBUG] Residual : 2.55e-05 (# of elements : 11686)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.4380, RMSE 0.0066
# [Open3D DEBUG] Residual : 1.81e-05 (# of elements : 12089)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.4386, RMSE 0.0058
# [Open3D DEBUG] Residual : 8.07e-06 (# of elements : 12106)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.4384, RMSE 0.0058
# [Open3D DEBUG] Residual : 6.76e-06 (# of elements : 12099)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.4380, RMSE 0.0058
# [Open3D DEBUG] Residual : 6.75e-06 (# of elements : 12090)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.4381, RMSE 0.0058
# [Open3D DEBUG] Residual : 6.76e-06 (# of elements : 12091)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.4380, RMSE 0.0058
# [Open3D DEBUG] Residual : 6.79e-06 (# of elements : 12090)
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.4380, RMSE 0.0058
# [Open3D DEBUG] Residual : 6.78e-06 (# of elements : 12090)
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.4381, RMSE 0.0058
# [Open3D DEBUG] Residual : 6.76e-06 (# of elements : 12091)
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.4381, RMSE 0.0057
# [Open3D DEBUG] Residual : 6.75e-06 (# of elements : 12092)
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.4381, RMSE 0.0057
# [Open3D DEBUG] Residual : 6.75e-06 (# of elements : 12092)
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.4629, RMSE 0.0068
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.5786, RMSE 0.0061
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.6260, RMSE 0.0056
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.6361, RMSE 0.0053
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.6378, RMSE 0.0053
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.6381, RMSE 0.0053
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.6381, RMSE 0.0053
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.6381, RMSE 0.0053
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.6381, RMSE 0.0053
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.6381, RMSE 0.0053
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.6381, RMSE 0.0053
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.6380, RMSE 0.0053
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.6380, RMSE 0.0053
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.6380, RMSE 0.0053
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.6380, RMSE 0.0053
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.7181, RMSE 0.0067
# [Open3D DEBUG] Residual : 2.75e-05 (# of elements : 88301)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.7202, RMSE 0.0069
# [Open3D DEBUG] Residual : 2.52e-05 (# of elements : 88560)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.7203, RMSE 0.0069
# [Open3D DEBUG] Residual : 2.49e-05 (# of elements : 88577)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.7205, RMSE 0.0069
# [Open3D DEBUG] Residual : 2.49e-05 (# of elements : 88593)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.7205, RMSE 0.0069
# [Open3D DEBUG] Residual : 2.48e-05 (# of elements : 88596)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.7205, RMSE 0.0069
# [Open3D DEBUG] Residual : 2.48e-05 (# of elements : 88593)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.7204, RMSE 0.0069
# [Open3D DEBUG] Residual : 2.48e-05 (# of elements : 88590)
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.7204, RMSE 0.0069
# [Open3D DEBUG] Residual : 2.48e-05 (# of elements : 88588)
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.7205, RMSE 0.0069
# [Open3D DEBUG] Residual : 2.48e-05 (# of elements : 88592)
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.7205, RMSE 0.0069
# [Open3D DEBUG] Residual : 2.48e-05 (# of elements : 88593)
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.7205, RMSE 0.0069
# [Open3D DEBUG] Residual : 2.48e-05 (# of elements : 88592)
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0359, RMSE 0.0071
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.0427, RMSE 0.0071
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.0572, RMSE 0.0072
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.0981, RMSE 0.0072
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.2010, RMSE 0.0069
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.3190, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.4003, RMSE 0.0059
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.4454, RMSE 0.0057
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.4627, RMSE 0.0055
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.4669, RMSE 0.0054
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.4676, RMSE 0.0054
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.4677, RMSE 0.0054
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.4676, RMSE 0.0053
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.4675, RMSE 0.0053
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.4673, RMSE 0.0053
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.4673, RMSE 0.0053
# [Open3D DEBUG] ICP Iteration #16: Fitness 0.4672, RMSE 0.0053
# [Open3D DEBUG] ICP Iteration #17: Fitness 0.4672, RMSE 0.0053
# [Open3D DEBUG] ICP Iteration #18: Fitness 0.4673, RMSE 0.0053
# [Open3D DEBUG] ICP Iteration #19: Fitness 0.4672, RMSE 0.0053
# [Open3D DEBUG] ICP Iteration #20: Fitness 0.4672, RMSE 0.0053
# [Open3D DEBUG] ICP Iteration #21: Fitness 0.4672, RMSE 0.0053
# [Open3D DEBUG] ICP Iteration #22: Fitness 0.4672, RMSE 0.0053
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.5367, RMSE 0.0070
# [Open3D DEBUG] Residual : 3.21e-05 (# of elements : 65991)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.5495, RMSE 0.0071
# [Open3D DEBUG] Residual : 3.02e-05 (# of elements : 67564)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.5584, RMSE 0.0071
# [Open3D DEBUG] Residual : 2.78e-05 (# of elements : 68667)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.5618, RMSE 0.0069
# [Open3D DEBUG] Residual : 2.58e-05 (# of elements : 69086)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.5619, RMSE 0.0068
# [Open3D DEBUG] Residual : 2.51e-05 (# of elements : 69099)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.5617, RMSE 0.0068
# [Open3D DEBUG] Residual : 2.48e-05 (# of elements : 69070)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.5616, RMSE 0.0068
# [Open3D DEBUG] Residual : 2.48e-05 (# of elements : 69056)
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.5616, RMSE 0.0068
# [Open3D DEBUG] Residual : 2.48e-05 (# of elements : 69055)
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.5616, RMSE 0.0068
# [Open3D DEBUG] Residual : 2.48e-05 (# of elements : 69054)
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.5616, RMSE 0.0068
# [Open3D DEBUG] Residual : 2.48e-05 (# of elements : 69053)
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0145, RMSE 0.0076
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.0549, RMSE 0.0069
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.1040, RMSE 0.0062
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.1294, RMSE 0.0057
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.1369, RMSE 0.0055
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.1386, RMSE 0.0054
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.1389, RMSE 0.0054
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.1390, RMSE 0.0054
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.1392, RMSE 0.0054
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.1393, RMSE 0.0054
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.1392, RMSE 0.0054
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.1620, RMSE 0.0070
# [Open3D DEBUG] Residual : 3.18e-05 (# of elements : 19916)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.1620, RMSE 0.0070
# [Open3D DEBUG] Residual : 3.17e-05 (# of elements : 19924)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.1621, RMSE 0.0071
# [Open3D DEBUG] Residual : 3.16e-05 (# of elements : 19927)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.1621, RMSE 0.0071
# [Open3D DEBUG] Residual : 3.16e-05 (# of elements : 19928)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.1621, RMSE 0.0071
# [Open3D DEBUG] Residual : 3.16e-05 (# of elements : 19927)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.1620, RMSE 0.0071
# [Open3D DEBUG] Residual : 3.16e-05 (# of elements : 19926)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.1620, RMSE 0.0071
# [Open3D DEBUG] Residual : 3.15e-05 (# of elements : 19925)
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.1155, RMSE 0.0062
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.1177, RMSE 0.0061
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.1194, RMSE 0.0061
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.1206, RMSE 0.0061
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.1218, RMSE 0.0061
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.1229, RMSE 0.0061
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.1239, RMSE 0.0062
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.1249, RMSE 0.0062
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.1258, RMSE 0.0062
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.1269, RMSE 0.0062
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.1283, RMSE 0.0062
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.1297, RMSE 0.0062
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.1316, RMSE 0.0061
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.1340, RMSE 0.0062
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.1367, RMSE 0.0062
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.1395, RMSE 0.0062
# [Open3D DEBUG] ICP Iteration #16: Fitness 0.1422, RMSE 0.0062
# [Open3D DEBUG] ICP Iteration #17: Fitness 0.1448, RMSE 0.0062
# [Open3D DEBUG] ICP Iteration #18: Fitness 0.1483, RMSE 0.0062
# [Open3D DEBUG] ICP Iteration #19: Fitness 0.1518, RMSE 0.0062
# [Open3D DEBUG] ICP Iteration #20: Fitness 0.1558, RMSE 0.0062
# [Open3D DEBUG] ICP Iteration #21: Fitness 0.1600, RMSE 0.0063
# [Open3D DEBUG] ICP Iteration #22: Fitness 0.1646, RMSE 0.0063
# [Open3D DEBUG] ICP Iteration #23: Fitness 0.1693, RMSE 0.0063
# [Open3D DEBUG] ICP Iteration #24: Fitness 0.1734, RMSE 0.0063
# [Open3D DEBUG] ICP Iteration #25: Fitness 0.1771, RMSE 0.0063
# [Open3D DEBUG] ICP Iteration #26: Fitness 0.1807, RMSE 0.0063
# [Open3D DEBUG] ICP Iteration #27: Fitness 0.1839, RMSE 0.0063
# [Open3D DEBUG] ICP Iteration #28: Fitness 0.1876, RMSE 0.0062
# [Open3D DEBUG] ICP Iteration #29: Fitness 0.1908, RMSE 0.0062
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.3627, RMSE 0.0115
# [Open3D DEBUG] Residual : 9.65e-05 (# of elements : 54137)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.6782, RMSE 0.0105
# [Open3D DEBUG] Residual : 8.34e-05 (# of elements : 101241)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.7821, RMSE 0.0076
# [Open3D DEBUG] Residual : 3.36e-05 (# of elements : 116753)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.7849, RMSE 0.0072
# [Open3D DEBUG] Residual : 2.74e-05 (# of elements : 117172)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.7849, RMSE 0.0072
# [Open3D DEBUG] Residual : 2.73e-05 (# of elements : 117171)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.7849, RMSE 0.0072
# [Open3D DEBUG] Residual : 2.72e-05 (# of elements : 117164)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.7849, RMSE 0.0072
# [Open3D DEBUG] Residual : 2.72e-05 (# of elements : 117165)
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0530, RMSE 0.0067
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.0563, RMSE 0.0066
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.0592, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.0616, RMSE 0.0063
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.0637, RMSE 0.0062
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.0653, RMSE 0.0062
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.0666, RMSE 0.0062
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.0677, RMSE 0.0062
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.0688, RMSE 0.0062
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.0701, RMSE 0.0063
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.0719, RMSE 0.0063
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.0742, RMSE 0.0063
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.0784, RMSE 0.0063
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.0843, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.0899, RMSE 0.0063
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.0948, RMSE 0.0063
# [Open3D DEBUG] ICP Iteration #16: Fitness 0.0980, RMSE 0.0062
# [Open3D DEBUG] ICP Iteration #17: Fitness 0.0998, RMSE 0.0061
# [Open3D DEBUG] ICP Iteration #18: Fitness 0.1014, RMSE 0.0061
# [Open3D DEBUG] ICP Iteration #19: Fitness 0.1023, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #20: Fitness 0.1028, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #21: Fitness 0.1034, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #22: Fitness 0.1040, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #23: Fitness 0.1042, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #24: Fitness 0.1044, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #25: Fitness 0.1048, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #26: Fitness 0.1051, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #27: Fitness 0.1055, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #28: Fitness 0.1057, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #29: Fitness 0.1060, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.1939, RMSE 0.0113
# [Open3D DEBUG] Residual : 9.06e-05 (# of elements : 28949)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.3063, RMSE 0.0099
# [Open3D DEBUG] Residual : 6.57e-05 (# of elements : 45726)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.3144, RMSE 0.0079
# [Open3D DEBUG] Residual : 3.38e-05 (# of elements : 46927)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.3144, RMSE 0.0078
# [Open3D DEBUG] Residual : 3.26e-05 (# of elements : 46934)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.3144, RMSE 0.0078
# [Open3D DEBUG] Residual : 3.24e-05 (# of elements : 46933)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.3143, RMSE 0.0077
# [Open3D DEBUG] Residual : 3.24e-05 (# of elements : 46921)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.3143, RMSE 0.0077
# [Open3D DEBUG] Residual : 3.24e-05 (# of elements : 46917)
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.3143, RMSE 0.0077
# [Open3D DEBUG] Residual : 3.23e-05 (# of elements : 46918)
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.3143, RMSE 0.0077
# [Open3D DEBUG] Residual : 3.24e-05 (# of elements : 46919)
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.3143, RMSE 0.0077
# [Open3D DEBUG] Residual : 3.24e-05 (# of elements : 46921)
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0056
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.0001, RMSE 0.0061
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.0001, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.0002, RMSE 0.0063
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.0002, RMSE 0.0062
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.0002, RMSE 0.0062
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.0002, RMSE 0.0062
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.0002, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.0002, RMSE 0.0066
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.0002, RMSE 0.0065
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0004, RMSE 0.0121
# [Open3D DEBUG] Residual : 8.36e-05 (# of elements : 58)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.0002, RMSE 0.0159
# [Open3D DEBUG] Residual : 9.88e-05 (# of elements : 32)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.0006, RMSE 0.0138
# [Open3D DEBUG] Residual : 1.08e-04 (# of elements : 93)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.0013, RMSE 0.0130
# [Open3D DEBUG] Residual : 8.31e-05 (# of elements : 188)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.0017, RMSE 0.0125
# [Open3D DEBUG] Residual : 6.85e-05 (# of elements : 251)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.0020, RMSE 0.0126
# [Open3D DEBUG] Residual : 7.02e-05 (# of elements : 298)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.0025, RMSE 0.0131
# [Open3D DEBUG] Residual : 8.83e-05 (# of elements : 371)
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.0032, RMSE 0.0121
# [Open3D DEBUG] Residual : 6.58e-05 (# of elements : 478)
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.0033, RMSE 0.0118
# [Open3D DEBUG] Residual : 6.51e-05 (# of elements : 489)
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.0033, RMSE 0.0118
# [Open3D DEBUG] Residual : 6.68e-05 (# of elements : 500)
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.0035, RMSE 0.0119
# [Open3D DEBUG] Residual : 6.75e-05 (# of elements : 521)
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.0036, RMSE 0.0119
# [Open3D DEBUG] Residual : 7.02e-05 (# of elements : 531)
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.0035, RMSE 0.0116
# [Open3D DEBUG] Residual : 6.61e-05 (# of elements : 529)
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.0036, RMSE 0.0117
# [Open3D DEBUG] Residual : 6.42e-05 (# of elements : 532)
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.0036, RMSE 0.0118
# [Open3D DEBUG] Residual : 6.62e-05 (# of elements : 535)
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.0036, RMSE 0.0118
# [Open3D DEBUG] Residual : 6.72e-05 (# of elements : 534)
# [Open3D DEBUG] ICP Iteration #16: Fitness 0.0036, RMSE 0.0119
# [Open3D DEBUG] Residual : 6.56e-05 (# of elements : 536)
# [Open3D DEBUG] ICP Iteration #17: Fitness 0.0036, RMSE 0.0119
# [Open3D DEBUG] Residual : 6.67e-05 (# of elements : 535)
# [Open3D DEBUG] ICP Iteration #18: Fitness 0.0036, RMSE 0.0119
# [Open3D DEBUG] Residual : 6.63e-05 (# of elements : 534)
# [Open3D DEBUG] ICP Iteration #19: Fitness 0.0036, RMSE 0.0120
# [Open3D DEBUG] Residual : 6.71e-05 (# of elements : 537)
# [Open3D DEBUG] ICP Iteration #20: Fitness 0.0036, RMSE 0.0120
# [Open3D DEBUG] Residual : 6.79e-05 (# of elements : 532)
# [Open3D DEBUG] ICP Iteration #21: Fitness 0.0035, RMSE 0.0119
# [Open3D DEBUG] Residual : 6.67e-05 (# of elements : 525)
# [Open3D DEBUG] ICP Iteration #22: Fitness 0.0035, RMSE 0.0117
# [Open3D DEBUG] Residual : 6.35e-05 (# of elements : 522)
# [Open3D DEBUG] ICP Iteration #23: Fitness 0.0035, RMSE 0.0117
# [Open3D DEBUG] Residual : 6.02e-05 (# of elements : 526)
# [Open3D DEBUG] ICP Iteration #24: Fitness 0.0036, RMSE 0.0118
# [Open3D DEBUG] Residual : 6.11e-05 (# of elements : 532)
# [Open3D DEBUG] ICP Iteration #25: Fitness 0.0036, RMSE 0.0117
# [Open3D DEBUG] Residual : 6.08e-05 (# of elements : 531)
# [Open3D DEBUG] ICP Iteration #26: Fitness 0.0035, RMSE 0.0116
# [Open3D DEBUG] Residual : 5.90e-05 (# of elements : 527)
# [Open3D DEBUG] ICP Iteration #27: Fitness 0.0035, RMSE 0.0116
# [Open3D DEBUG] Residual : 5.62e-05 (# of elements : 527)
# [Open3D DEBUG] ICP Iteration #28: Fitness 0.0035, RMSE 0.0115
# [Open3D DEBUG] Residual : 5.33e-05 (# of elements : 524)
# [Open3D DEBUG] ICP Iteration #29: Fitness 0.0035, RMSE 0.0115
# [Open3D DEBUG] Residual : 5.43e-05 (# of elements : 525)
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0000, RMSE 0.0000
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.3511, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.3601, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.3665, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.3720, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.3778, RMSE 0.0063
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.3847, RMSE 0.0063
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.3947, RMSE 0.0062
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.4040, RMSE 0.0061
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.4103, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.4136, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.4156, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.4166, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.4172, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.4176, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.4178, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.4179, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #16: Fitness 0.4181, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #17: Fitness 0.4183, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #18: Fitness 0.4184, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #19: Fitness 0.4184, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #20: Fitness 0.4185, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #21: Fitness 0.4185, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #22: Fitness 0.4185, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #23: Fitness 0.4185, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #24: Fitness 0.4186, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #25: Fitness 0.4186, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #26: Fitness 0.4187, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #27: Fitness 0.4187, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #28: Fitness 0.4187, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #29: Fitness 0.4187, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.5406, RMSE 0.0085
# [Open3D DEBUG] Residual : 4.48e-05 (# of elements : 102629)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.5461, RMSE 0.0082
# [Open3D DEBUG] Residual : 3.91e-05 (# of elements : 103667)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.5475, RMSE 0.0081
# [Open3D DEBUG] Residual : 3.81e-05 (# of elements : 103947)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.5477, RMSE 0.0081
# [Open3D DEBUG] Residual : 3.77e-05 (# of elements : 103975)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.5477, RMSE 0.0081
# [Open3D DEBUG] Residual : 3.77e-05 (# of elements : 103984)
# ...
# [Open3D DEBUG] ICP Iteration #20: Fitness 0.0008, RMSE 0.0060
# [Open3D DEBUG] ICP Iteration #21: Fitness 0.0008, RMSE 0.0059
# [Open3D DEBUG] ICP Iteration #22: Fitness 0.0008, RMSE 0.0059
# [Open3D DEBUG] ICP Iteration #23: Fitness 0.0008, RMSE 0.0058
# [Open3D DEBUG] ICP Iteration #24: Fitness 0.0008, RMSE 0.0058
# [Open3D DEBUG] ICP Iteration #25: Fitness 0.0008, RMSE 0.0058
# [Open3D DEBUG] ICP Iteration #26: Fitness 0.0008, RMSE 0.0057
# [Open3D DEBUG] ICP Iteration #27: Fitness 0.0008, RMSE 0.0057
# [Open3D DEBUG] ICP Iteration #28: Fitness 0.0008, RMSE 0.0057
# [Open3D DEBUG] ICP Iteration #29: Fitness 0.0008, RMSE 0.0057
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0014, RMSE 0.0105
# [Open3D DEBUG] Residual : 2.88e-05 (# of elements : 190)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.0013, RMSE 0.0123
# [Open3D DEBUG] Residual : 6.22e-05 (# of elements : 180)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.0019, RMSE 0.0124
# [Open3D DEBUG] Residual : 6.69e-05 (# of elements : 264)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.0021, RMSE 0.0122
# [Open3D DEBUG] Residual : 5.89e-05 (# of elements : 291)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.0022, RMSE 0.0124
# [Open3D DEBUG] Residual : 6.43e-05 (# of elements : 306)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.0022, RMSE 0.0123
# [Open3D DEBUG] Residual : 6.26e-05 (# of elements : 302)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.0021, RMSE 0.0122
# [Open3D DEBUG] Residual : 6.38e-05 (# of elements : 292)
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.0022, RMSE 0.0125
# [Open3D DEBUG] Residual : 6.48e-05 (# of elements : 302)
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.0022, RMSE 0.0128
# [Open3D DEBUG] Residual : 6.40e-05 (# of elements : 313)
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.0022, RMSE 0.0133
# [Open3D DEBUG] Residual : 6.48e-05 (# of elements : 308)
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.0020, RMSE 0.0134
# [Open3D DEBUG] Residual : 6.40e-05 (# of elements : 280)
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.0017, RMSE 0.0137
# [Open3D DEBUG] Residual : 6.84e-05 (# of elements : 243)
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.0015, RMSE 0.0135
# [Open3D DEBUG] Residual : 7.25e-05 (# of elements : 209)
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.0013, RMSE 0.0137
# [Open3D DEBUG] Residual : 7.22e-05 (# of elements : 186)
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.0013, RMSE 0.0125
# [Open3D DEBUG] Residual : 4.38e-05 (# of elements : 178)
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.0010, RMSE 0.0151
# [Open3D DEBUG] Residual : 1.18e-04 (# of elements : 138)
# [Open3D DEBUG] ICP Iteration #16: Fitness 0.0015, RMSE 0.0138
# [Open3D DEBUG] Residual : 8.09e-05 (# of elements : 214)
# [Open3D DEBUG] ICP Iteration #17: Fitness 0.0015, RMSE 0.0129
# [Open3D DEBUG] Residual : 7.99e-05 (# of elements : 205)
# [Open3D DEBUG] ICP Iteration #18: Fitness 0.0019, RMSE 0.0130
# [Open3D DEBUG] Residual : 7.49e-05 (# of elements : 260)
# [Open3D DEBUG] ICP Iteration #19: Fitness 0.0019, RMSE 0.0130
# [Open3D DEBUG] Residual : 8.74e-05 (# of elements : 272)
# [Open3D DEBUG] ICP Iteration #20: Fitness 0.0020, RMSE 0.0127
# [Open3D DEBUG] Residual : 8.84e-05 (# of elements : 287)
# [Open3D DEBUG] ICP Iteration #21: Fitness 0.0020, RMSE 0.0126
# [Open3D DEBUG] Residual : 8.58e-05 (# of elements : 287)
# [Open3D DEBUG] ICP Iteration #22: Fitness 0.0021, RMSE 0.0121
# [Open3D DEBUG] Residual : 7.17e-05 (# of elements : 297)
# [Open3D DEBUG] ICP Iteration #23: Fitness 0.0024, RMSE 0.0115
# [Open3D DEBUG] Residual : 6.02e-05 (# of elements : 338)
# [Open3D DEBUG] ICP Iteration #24: Fitness 0.0029, RMSE 0.0117
# [Open3D DEBUG] Residual : 5.89e-05 (# of elements : 401)
# [Open3D DEBUG] ICP Iteration #25: Fitness 0.0031, RMSE 0.0118
# [Open3D DEBUG] Residual : 6.36e-05 (# of elements : 430)
# [Open3D DEBUG] ICP Iteration #26: Fitness 0.0032, RMSE 0.0117
# [Open3D DEBUG] Residual : 6.25e-05 (# of elements : 452)
# [Open3D DEBUG] ICP Iteration #27: Fitness 0.0032, RMSE 0.0117
# [Open3D DEBUG] Residual : 6.57e-05 (# of elements : 455)
# [Open3D DEBUG] ICP Iteration #28: Fitness 0.0031, RMSE 0.0116
# [Open3D DEBUG] Residual : 5.94e-05 (# of elements : 437)
# [Open3D DEBUG] ICP Iteration #29: Fitness 0.0032, RMSE 0.0116
# [Open3D DEBUG] Residual : 5.82e-05 (# of elements : 449)
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.3401, RMSE 0.0061
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.3547, RMSE 0.0054
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.3602, RMSE 0.0050
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.3621, RMSE 0.0049
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.3631, RMSE 0.0049
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.3636, RMSE 0.0049
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.3637, RMSE 0.0049
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.3638, RMSE 0.0049
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.3638, RMSE 0.0049
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.3638, RMSE 0.0049
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.3638, RMSE 0.0049
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.3638, RMSE 0.0049
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.3638, RMSE 0.0049
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.3638, RMSE 0.0049
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.3639, RMSE 0.0049
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.3639, RMSE 0.0049
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.4454, RMSE 0.0075
# [Open3D DEBUG] Residual : 2.02e-05 (# of elements : 49281)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.4470, RMSE 0.0078
# [Open3D DEBUG] Residual : 1.78e-05 (# of elements : 49468)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.4474, RMSE 0.0079
# [Open3D DEBUG] Residual : 1.76e-05 (# of elements : 49503)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.4474, RMSE 0.0079
# [Open3D DEBUG] Residual : 1.76e-05 (# of elements : 49511)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.4474, RMSE 0.0080
# [Open3D DEBUG] Residual : 1.76e-05 (# of elements : 49513)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.4475, RMSE 0.0080
# [Open3D DEBUG] Residual : 1.76e-05 (# of elements : 49516)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.4475, RMSE 0.0080
# [Open3D DEBUG] Residual : 1.76e-05 (# of elements : 49516)
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0702, RMSE 0.0057
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.0734, RMSE 0.0051
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.0747, RMSE 0.0050
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.0753, RMSE 0.0050
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.0756, RMSE 0.0050
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.0757, RMSE 0.0050
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.0758, RMSE 0.0050
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.0759, RMSE 0.0050
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.0759, RMSE 0.0050
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.0760, RMSE 0.0050
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0986, RMSE 0.0083
# [Open3D DEBUG] Residual : 2.58e-05 (# of elements : 10906)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.0986, RMSE 0.0084
# [Open3D DEBUG] Residual : 2.36e-05 (# of elements : 10910)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.0984, RMSE 0.0083
# [Open3D DEBUG] Residual : 2.28e-05 (# of elements : 10891)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.0984, RMSE 0.0082
# [Open3D DEBUG] Residual : 2.26e-05 (# of elements : 10893)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.0984, RMSE 0.0082
# [Open3D DEBUG] Residual : 2.27e-05 (# of elements : 10894)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.0984, RMSE 0.0082
# [Open3D DEBUG] Residual : 2.27e-05 (# of elements : 10894)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.0985, RMSE 0.0082
# [Open3D DEBUG] Residual : 2.26e-05 (# of elements : 10895)
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.0984, RMSE 0.0082
# [Open3D DEBUG] Residual : 2.26e-05 (# of elements : 10894)
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.3582, RMSE 0.0054
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.3585, RMSE 0.0052
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.3577, RMSE 0.0048
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.3564, RMSE 0.0045
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.3557, RMSE 0.0044
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.3555, RMSE 0.0044
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.3554, RMSE 0.0044
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.3553, RMSE 0.0044
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.3552, RMSE 0.0044
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.3552, RMSE 0.0044
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.4058, RMSE 0.0065
# [Open3D DEBUG] Residual : 1.35e-05 (# of elements : 24252)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.4078, RMSE 0.0071
# [Open3D DEBUG] Residual : 1.21e-05 (# of elements : 24370)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.4082, RMSE 0.0073
# [Open3D DEBUG] Residual : 1.21e-05 (# of elements : 24394)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.4082, RMSE 0.0073
# [Open3D DEBUG] Residual : 1.20e-05 (# of elements : 24395)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.4083, RMSE 0.0073
# [Open3D DEBUG] Residual : 1.20e-05 (# of elements : 24396)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.4082, RMSE 0.0073
# [Open3D DEBUG] Residual : 1.20e-05 (# of elements : 24395)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.4082, RMSE 0.0073
# [Open3D DEBUG] Residual : 1.20e-05 (# of elements : 24395)
# [Open3D DEBUG] Validating PoseGraph - finished.
# [Open3D DEBUG] [GlobalOptimizationLM] Optimizing PoseGraph having 11 nodes and 55 edges.
# [Open3D DEBUG] Line process weight : 1.821975
# [Open3D DEBUG] [Initial     ] residual : 1.730948e+04, lambda : 8.768404e+01
# [Open3D DEBUG] [Iteration 00] residual : 1.596426e+01, valid edges : 39, time : 0.000 sec.
# [Open3D DEBUG] [Iteration 01] residual : 1.227816e+01, valid edges : 41, time : 0.000 sec.
# [Open3D DEBUG] [Iteration 02] residual : 9.967126e+00, valid edges : 41, time : 0.000 sec.
# [Open3D DEBUG] [Iteration 03] residual : 9.961396e+00, valid edges : 41, time : 0.000 sec.
# [Open3D DEBUG] [Iteration 04] residual : 9.961302e+00, valid edges : 41, time : 0.000 sec.
# [Open3D DEBUG] Current_residual - new_residual < 1.000000e-06 * current_residual
# [Open3D DEBUG] [GlobalOptimizationLM] total time : 0.002 sec.
# [Open3D DEBUG] [GlobalOptimizationLM] Optimizing PoseGraph having 11 nodes and 51 edges.
# [Open3D DEBUG] Line process weight : 1.920586
# [Open3D DEBUG] [Initial     ] residual : 2.985343e+00, lambda : 9.367049e+01
# [Open3D DEBUG] [Iteration 00] residual : 2.983009e+00, valid edges : 41, time : 0.000 sec.
# [Open3D DEBUG] [Iteration 01] residual : 2.982792e+00, valid edges : 41, time : 0.000 sec.
# [Open3D DEBUG] [Iteration 02] residual : 2.982783e+00, valid edges : 41, time : 0.000 sec.
# [Open3D DEBUG] Current_residual - new_residual < 1.000000e-06 * current_residual
# [Open3D DEBUG] [GlobalOptimizationLM] total time : 0.001 sec.
# [Open3D DEBUG] CompensateReferencePoseGraphNode : reference : 0
# [[ 1.00000000e+00 -1.07573184e-18  2.16840434e-19  0.00000000e+00]
#  [ 2.39286808e-18  1.00000000e+00  0.00000000e+00  1.73472348e-18]
#  [ 2.16840434e-19  0.00000000e+00  1.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# [[ 0.99987648 -0.01526135  0.00375806 -0.0015455 ]
#  [ 0.01516049  0.99955872  0.02554438 -0.04144232]
#  [-0.00414625 -0.02548425  0.99966663 -0.00186823]
#  [ 0.          0.          0.          1.        ]]
# [[ 9.99766058e-01 -2.15579713e-02 -1.75594631e-03  1.22995841e-02]
#  [ 2.15570715e-02  9.99767479e-01 -5.29737025e-04 -1.23832812e-02]
#  [ 1.76695807e-03  4.91760037e-04  9.99998318e-01 -2.82654279e-03]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# [[ 9.99783449e-01 -1.99188158e-02 -6.02463523e-03  1.49735227e-02]
#  [ 1.99206790e-02  9.99801532e-01  2.49400544e-04 -1.41503377e-02]
#  [ 6.01847177e-03 -3.69361361e-04  9.99981821e-01 -7.16466885e-03]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# [[ 0.99945902 -0.03158653 -0.00916248  0.02126203]
#  [ 0.03160399  0.99949891  0.0017671  -0.02536228]
#  [ 0.00910208 -0.00205572  0.99995646 -0.01031401]
#  [ 0.          0.          0.          1.        ]]
# [[ 0.9995121  -0.02885838 -0.0119478   0.02185018]
#  [ 0.02892519  0.99956668  0.00545739 -0.02853713]
#  [ 0.01178513 -0.00580032  0.99991373 -0.01094541]
#  [ 0.          0.          0.          1.        ]]
# [[ 0.99914712 -0.03912737 -0.01319378  0.02098456]
#  [ 0.03925312  0.99918499  0.00941046 -0.03648102]
#  [ 0.01281482 -0.00992033  0.99986868 -0.01220616]
#  [ 0.          0.          0.          1.        ]]
# [[ 0.99964129 -0.02337135 -0.0130791   0.01900247]
#  [ 0.02354768  0.99963163  0.0134945  -0.03197008]
#  [ 0.0127589  -0.01379764  0.9998234  -0.0126218 ]
#  [ 0.          0.          0.          1.        ]]
# [[ 0.99960436 -0.02559065 -0.01167219  0.01597974]
#  [ 0.02579472  0.99951088  0.01768153 -0.03962708]
#  [ 0.011214   -0.01797561  0.99977554 -0.01134931]
#  [ 0.          0.          0.          1.        ]]
# [[ 0.99965468 -0.02458163 -0.00928755  0.01043127]
#  [ 0.02477552  0.99946457  0.02137169 -0.0436512 ]
#  [ 0.00875722 -0.02159441  0.99972846 -0.0101774 ]
#  [ 0.          0.          0.          1.        ]]
# [[ 0.9996742  -0.02509754 -0.00464738  0.00497599]
#  [ 0.02519715  0.99942282  0.0227845  -0.04506229]
#  [ 0.00407286 -0.02289417  0.9997296  -0.0058306 ]
#  [ 0.          0.          0.          1.        ]]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, 1.0610, -0.7705) - (3.8619, 7.4328, 3.0183)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0435, -0.7705) - (3.8619, 7.4328, 3.0183)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0435, -0.7991) - (4.9884, 8.1441, 3.0183)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0435, -0.7991) - (8.5542, 8.6845, 3.0183)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0435, -0.7991) - (11.0733, 8.6845, 3.0183)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0435, -0.7991) - (11.0733, 8.6845, 3.0183)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0435, -0.7991) - (11.0733, 8.6845, 3.0723)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0435, -0.7991) - (11.0733, 8.6845, 3.0723)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0435, -0.7991) - (11.0733, 8.6845, 3.0723)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0435, -0.7991) - (11.0733, 8.6845, 3.0723)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0435, -0.7991) - (11.0733, 8.6845, 3.0723)]
# [Open3D DEBUG] [Visualizer] Point size set to 4.00.
# [Open3D DEBUG] [Visualizer] Point size set to 3.00.
# [Open3D DEBUG] [Visualizer] Point size set to 2.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, 1.0610, -0.7705) - (3.8619, 7.4328, 3.0183)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0435, -0.7705) - (3.8619, 7.4328, 3.0183)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0435, -0.7991) - (4.9884, 8.1441, 3.0183)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0435, -0.7991) - (8.5542, 8.6845, 3.0183)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0435, -0.7991) - (11.0733, 8.6845, 3.0183)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0435, -0.7991) - (11.0733, 8.6845, 3.0183)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0435, -0.7991) - (11.0733, 8.6845, 3.0723)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0435, -0.7991) - (11.0733, 8.6845, 3.0723)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0435, -0.7991) - (11.0733, 8.6845, 3.0723)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0435, -0.7991) - (11.0733, 8.6845, 3.0723)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0435, -0.7991) - (11.0733, 8.6845, 3.0723)]
# [Open3D DEBUG] Pointcloud down sampled from 10702955 points to 2615375 points.
# [Open3D DEBUG] Add geometry and update bounding box to [(-3.3800, -2.0425, -0.7991) - (11.0733, 8.6845, 3.0723)]
