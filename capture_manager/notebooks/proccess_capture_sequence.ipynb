# %%
import open3d as o3d
import numpy as np
from copy import deepcopy
from pathlib import Path
from typing import List, Tuple


def load_capture_sequence(
    dir_path: Path,
    num_captures: int = None,
) -> Tuple[List[o3d.geometry.PointCloud], List[np.ndarray]]:
    pcd_files = sorted(dir_path.glob("*.ply"))
    pose_files = sorted(dir_path.glob("*.txt"))

    if num_captures:
        pcd_files = pcd_files[:num_captures]
        pose_files = pose_files[:num_captures]

    pcds = [o3d.io.read_point_cloud(str(pcd_file)) for pcd_file in pcd_files]
    poses = [np.loadtxt(str(pose_file)) for pose_file in pose_files]

    if len(pcds) == 0:
        raise Exception("No point clouds found")
    if len(poses) == 0:
        raise Exception("No poses found")
    assert len(pcds) == len(poses)

    print(f"Loaded {len(pcds)} point clouds and {len(poses)} poses")

    return pcds, poses


def multiway_pt2pl_registration(
    pcds: List[o3d.geometry.PointCloud],
    reg_max_correspondence_fine: float,
    global_optimization_max_correspondence: float,
    reg_max_correspondence_coarse: float = None,
) -> o3d.pipelines.registration.PoseGraph:
    pose_graph = o3d.pipelines.registration.PoseGraph()
    odometry = np.identity(4)
    pose_graph.nodes.append(o3d.pipelines.registration.PoseGraphNode(odometry))
    n_pcds = len(pcds)

    for source_id in range(n_pcds):
        for target_id in range(source_id + 1, n_pcds):
            if reg_max_correspondence_coarse is not None:
                icp_coarse = o3d.pipelines.registration.registration_icp(
                    source=pcds[source_id],
                    target=pcds[target_id],
                    max_correspondence_distance=reg_max_correspondence_coarse,
                    init=np.identity(4),
                )
            transformation_icp = o3d.pipelines.registration.registration_icp(
                source=pcds[source_id],
                target=pcds[target_id],
                max_correspondence_distance=reg_max_correspondence_fine,
                init=icp_coarse.transformation,
                estimation_method=o3d.pipelines.registration.TransformationEstimationPointToPlane(),
            ).transformation

            information_icp = o3d.pipelines.registration.get_information_matrix_from_point_clouds(
                source=pcds[source_id],
                target=pcds[target_id],
                max_correspondence_distance=reg_max_correspondence_fine,
                transformation=transformation_icp,
            )
            if target_id == source_id + 1:  # odometry case
                odometry = np.dot(transformation_icp, odometry)
                pose_graph.nodes.append(
                    o3d.pipelines.registration.PoseGraphNode(np.linalg.inv(odometry))
                )
                pose_graph.edges.append(
                    o3d.pipelines.registration.PoseGraphEdge(
                        source_id, target_id, transformation_icp, information_icp, uncertain=False
                    )
                )
            else:  # loop closure case
                pose_graph.edges.append(
                    o3d.pipelines.registration.PoseGraphEdge(
                        source_id, target_id, transformation_icp, information_icp, uncertain=True
                    )
                )
    option = o3d.pipelines.registration.GlobalOptimizationOption(
        max_correspondence_distance=global_optimization_max_correspondence,
        edge_prune_threshold=0.25,
        reference_node=0,
    )

    o3d.pipelines.registration.global_optimization(
        pose_graph,
        o3d.pipelines.registration.GlobalOptimizationLevenbergMarquardt(),
        o3d.pipelines.registration.GlobalOptimizationConvergenceCriteria(),
        option,
    )

    return pose_graph


def downsampled_multiway_pt2pl_registration(
    pcds: List[o3d.geometry.PointCloud],
    voxel_size: float = 0.002,
    reg_dist_max_corr_coarse: float = 0.004,
    reg_dist_max_corr_fine: float = 0.002,
    global_optimization_max_correspondence: float = 0.002,
    visualize: bool = False,
) -> List[o3d.geometry.PointCloud]:
    down_pcds = []
    for i in range(len(pcds)):
        down_pcds.append(deepcopy(pcds[i]).voxel_down_sample(voxel_size=voxel_size))

    if visualize:
        o3d.visualization.draw_geometries(down_pcds, window_name="downsampled for registration")

    pose_graph = multiway_pt2pl_registration(
        down_pcds,
        reg_dist_max_corr_coarse,
        reg_dist_max_corr_fine,
        global_optimization_max_correspondence,
    )

    for point_id in range(len(pcds)):
        print(pose_graph.nodes[point_id].pose)
        pcds[point_id].transform(pose_graph.nodes[point_id].pose)

    if visualize:
        o3d.visualization.draw_geometries(pcds, window_name="registration")

    return pcds


def merge_pcds(point_clouds: List[o3d.geometry.PointCloud]) -> o3d.geometry.PointCloud:
    points = []
    colors = []
    normals = []

    for pcd in point_clouds:
        points.append(np.asarray(pcd.points))

        if pcd.has_colors():
            colors.append(np.asarray(pcd.colors))

        if pcd.has_normals():
            normals.append(np.asarray(pcd.normals))

    merged_pcd = o3d.geometry.PointCloud()
    merged_pcd.points = o3d.utility.Vector3dVector(np.vstack(points))

    if colors:
        merged_pcd.colors = o3d.utility.Vector3dVector(np.vstack(colors))

    if normals:
        merged_pcd.normals = o3d.utility.Vector3dVector(np.vstack(normals))

    return merged_pcd
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
dir_path = Path("/home/v/capture/log2")

# %%
with o3d.utility.VerbosityContextManager(o3d.utility.VerbosityLevel.Debug):
    pcds, tfs = load_capture_sequence(dir_path)

    pcds = [pcd.remove_non_finite_points() for pcd in pcds]
    pcds = [pcd.transform(tf) for pcd, tf in zip(pcds, tfs)]

    marker = o3d.geometry.TriangleMesh.create_coordinate_frame(size=0.1)

    o3d.visualization.draw_geometries(pcds + [marker], window_name="robot coordinate space")

    pcds = [pcd.remove_statistical_outlier(nb_neighbors=20, std_ratio=2.0)[0] for pcd in pcds]

    o3d.visualization.draw_geometries(pcds, window_name="outlier removal")

    for pcd in pcds:
        pcd.estimate_normals()

    voxel_size = 0.01
    pcds = downsampled_multiway_pt2pl_registration(
        pcds,
        voxel_size=voxel_size,
        reg_dist_max_corr_coarse=voxel_size * 2,
        reg_dist_max_corr_fine=voxel_size,
        global_optimization_max_correspondence=voxel_size,
        visualize=True,
    )

    o3d.visualization.draw_geometries(pcds, window_name="registration")

    merged_pcd = merge_pcds(pcds).voxel_down_sample(voxel_size=0.005)

    o3d.visualization.draw_geometries([merged_pcd], window_name="merged point cloud")
# Out:
# [Open3D DEBUG] Format auto File /home/v/capture/log2/0_2023_09_27__13_40_22_pcd.ply
# [Open3D DEBUG] Read geometry::PointCloud: 3145728 vertices.
# [Open3D DEBUG] Format auto File /home/v/capture/log2/1_2023_09_27__13_40_36_pcd.ply
# [Open3D DEBUG] Read geometry::PointCloud: 3145728 vertices.
# [Open3D DEBUG] Format auto File /home/v/capture/log2/2_2023_09_27__13_40_53_pcd.ply
# [Open3D DEBUG] Read geometry::PointCloud: 3145728 vertices.
# Loaded 3 point clouds and 3 poses
# [Open3D DEBUG] [RemoveNonFinitePoints] 1546147 nan points have been removed.
# [Open3D DEBUG] [RemoveNonFinitePoints] 1541770 nan points have been removed.
# [Open3D DEBUG] [RemoveNonFinitePoints] 1549346 nan points have been removed.
# [Open3D DEBUG] Add geometry and update bounding box to [(0.0772, -0.7020, -0.7349) - (1.4652, 0.8120, -0.4469)]
# [Open3D DEBUG] Add geometry and update bounding box to [(0.0772, -0.7161, -0.7349) - (1.7287, 0.8279, -0.4003)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-0.1688, -0.7221, -0.7349) - (1.7287, 0.8279, -0.3780)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-0.1688, -0.7221, -0.7349) - (1.7287, 0.8279, 0.1000)]
# [Open3D DEBUG] [Visualizer] Point size set to 4.00.
# [Open3D DEBUG] [Visualizer] Point size set to 3.00.
# [Open3D DEBUG] [Visualizer] Point size set to 2.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] Pointcloud down sampled from 1599581 points to 1543385 points.
# [Open3D DEBUG] Pointcloud down sampled from 1603958 points to 1554079 points.
# [Open3D DEBUG] Pointcloud down sampled from 1596382 points to 1545933 points.
# [Open3D DEBUG] Add geometry and update bounding box to [(0.0772, -0.7010, -0.7349) - (1.4652, 0.8120, -0.4499)]
# [Open3D DEBUG] Add geometry and update bounding box to [(0.0772, -0.7151, -0.7349) - (1.7281, 0.8269, -0.4003)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-0.1688, -0.7221, -0.7349) - (1.7281, 0.8269, -0.3784)]
# [Open3D DEBUG] [Visualizer] Point size set to 4.00.
# [Open3D DEBUG] [Visualizer] Point size set to 3.00.
# [Open3D DEBUG] [Visualizer] Point size set to 2.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] Pointcloud down sampled from 1543385 points to 20673 points.
# [Open3D DEBUG] Pointcloud down sampled from 1554079 points to 25826 points.
# [Open3D DEBUG] Pointcloud down sampled from 1545933 points to 23791 points.
# [Open3D DEBUG] Add geometry and update bounding box to [(0.0799, -0.6987, -0.7339) - (1.4632, 0.8091, -0.4533)]
# [Open3D DEBUG] Add geometry and update bounding box to [(0.0799, -0.7128, -0.7339) - (1.7248, 0.8233, -0.4003)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-0.1669, -0.7195, -0.7339) - (1.7248, 0.8249, -0.3802)]
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0573, RMSE 0.0077
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.1494, RMSE 0.0071
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.2959, RMSE 0.0065
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.7033, RMSE 0.0058
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.8348, RMSE 0.0036
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.8360, RMSE 0.0034
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.8359, RMSE 0.0034
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.8358, RMSE 0.0034
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.8357, RMSE 0.0034
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.8877, RMSE 0.0048
# [Open3D DEBUG] Residual : 8.34e-06 (# of elements : 18352)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.8919, RMSE 0.0058
# [Open3D DEBUG] Residual : 7.91e-06 (# of elements : 18438)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.8933, RMSE 0.0052
# [Open3D DEBUG] Residual : 7.34e-06 (# of elements : 18468)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.8942, RMSE 0.0058
# [Open3D DEBUG] Residual : 7.51e-06 (# of elements : 18486)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.8947, RMSE 0.0061
# [Open3D DEBUG] Residual : 7.54e-06 (# of elements : 18496)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.8946, RMSE 0.0061
# [Open3D DEBUG] Residual : 7.48e-06 (# of elements : 18494)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.8949, RMSE 0.0060
# [Open3D DEBUG] Residual : 7.47e-06 (# of elements : 18500)
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.8948, RMSE 0.0060
# [Open3D DEBUG] Residual : 7.39e-06 (# of elements : 18499)
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.8949, RMSE 0.0059
# [Open3D DEBUG] Residual : 7.39e-06 (# of elements : 18500)
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.8949, RMSE 0.0057
# [Open3D DEBUG] Residual : 7.36e-06 (# of elements : 18501)
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.8946, RMSE 0.0053
# [Open3D DEBUG] Residual : 7.27e-06 (# of elements : 18494)
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.8945, RMSE 0.0052
# [Open3D DEBUG] Residual : 7.20e-06 (# of elements : 18493)
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.8945, RMSE 0.0052
# [Open3D DEBUG] Residual : 7.18e-06 (# of elements : 18491)
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.8944, RMSE 0.0051
# [Open3D DEBUG] Residual : 7.18e-06 (# of elements : 18490)
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.8944, RMSE 0.0051
# [Open3D DEBUG] Residual : 7.16e-06 (# of elements : 18489)
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.8944, RMSE 0.0051
# [Open3D DEBUG] Residual : 7.16e-06 (# of elements : 18489)
# [Open3D DEBUG] ICP Iteration #16: Fitness 0.8944, RMSE 0.0051
# [Open3D DEBUG] Residual : 7.16e-06 (# of elements : 18490)
# [Open3D DEBUG] ICP Iteration #17: Fitness 0.8944, RMSE 0.0051
# [Open3D DEBUG] Residual : 7.16e-06 (# of elements : 18489)
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.2910, RMSE 0.0067
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.4386, RMSE 0.0053
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.6311, RMSE 0.0054
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.7975, RMSE 0.0042
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.8010, RMSE 0.0036
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.8009, RMSE 0.0036
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.8011, RMSE 0.0036
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.8011, RMSE 0.0036
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.8676, RMSE 0.0052
# [Open3D DEBUG] Residual : 1.10e-05 (# of elements : 17935)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.8787, RMSE 0.0061
# [Open3D DEBUG] Residual : 6.34e-06 (# of elements : 18165)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.8824, RMSE 0.0047
# [Open3D DEBUG] Residual : 5.01e-06 (# of elements : 18242)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.8837, RMSE 0.0052
# [Open3D DEBUG] Residual : 4.96e-06 (# of elements : 18269)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.8837, RMSE 0.0054
# [Open3D DEBUG] Residual : 4.95e-06 (# of elements : 18269)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.8839, RMSE 0.0055
# [Open3D DEBUG] Residual : 5.00e-06 (# of elements : 18273)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.8840, RMSE 0.0055
# [Open3D DEBUG] Residual : 5.05e-06 (# of elements : 18274)
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.8840, RMSE 0.0056
# [Open3D DEBUG] Residual : 5.09e-06 (# of elements : 18275)
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.8841, RMSE 0.0056
# [Open3D DEBUG] Residual : 5.10e-06 (# of elements : 18276)
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.8840, RMSE 0.0057
# [Open3D DEBUG] Residual : 5.09e-06 (# of elements : 18274)
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.8841, RMSE 0.0057
# [Open3D DEBUG] Residual : 5.08e-06 (# of elements : 18276)
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.8841, RMSE 0.0058
# [Open3D DEBUG] Residual : 5.06e-06 (# of elements : 18276)
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.8841, RMSE 0.0058
# [Open3D DEBUG] Residual : 5.05e-06 (# of elements : 18278)
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.8839, RMSE 0.0058
# [Open3D DEBUG] Residual : 5.03e-06 (# of elements : 18272)
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.8839, RMSE 0.0058
# [Open3D DEBUG] Residual : 4.98e-06 (# of elements : 18272)
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.8840, RMSE 0.0055
# [Open3D DEBUG] Residual : 4.98e-06 (# of elements : 18274)
# [Open3D DEBUG] ICP Iteration #16: Fitness 0.8841, RMSE 0.0052
# [Open3D DEBUG] Residual : 4.90e-06 (# of elements : 18278)
# [Open3D DEBUG] ICP Iteration #17: Fitness 0.8839, RMSE 0.0051
# [Open3D DEBUG] Residual : 4.91e-06 (# of elements : 18273)
# [Open3D DEBUG] ICP Iteration #18: Fitness 0.8840, RMSE 0.0050
# [Open3D DEBUG] Residual : 4.94e-06 (# of elements : 18274)
# [Open3D DEBUG] ICP Iteration #19: Fitness 0.8840, RMSE 0.0050
# [Open3D DEBUG] Residual : 4.94e-06 (# of elements : 18274)
# [Open3D DEBUG] ICP Iteration #20: Fitness 0.8841, RMSE 0.0050
# [Open3D DEBUG] Residual : 4.96e-06 (# of elements : 18276)
# [Open3D DEBUG] ICP Iteration #21: Fitness 0.8840, RMSE 0.0050
# [Open3D DEBUG] Residual : 4.95e-06 (# of elements : 18275)
# [Open3D DEBUG] ICP Iteration #22: Fitness 0.8840, RMSE 0.0050
# [Open3D DEBUG] Residual : 4.95e-06 (# of elements : 18275)
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.3008, RMSE 0.0071
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.4724, RMSE 0.0058
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.6078, RMSE 0.0038
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.6076, RMSE 0.0034
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.6076, RMSE 0.0034
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.6516, RMSE 0.0050
# [Open3D DEBUG] Residual : 7.46e-06 (# of elements : 16828)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.6511, RMSE 0.0051
# [Open3D DEBUG] Residual : 7.37e-06 (# of elements : 16815)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.6509, RMSE 0.0051
# [Open3D DEBUG] Residual : 7.36e-06 (# of elements : 16811)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.6509, RMSE 0.0051
# [Open3D DEBUG] Residual : 7.38e-06 (# of elements : 16810)
# [Open3D DEBUG] Validating PoseGraph - finished.
# [Open3D DEBUG] [GlobalOptimizationLM] Optimizing PoseGraph having 3 nodes and 3 edges.
# [Open3D DEBUG] Line process weight : 1.785800
# [Open3D DEBUG] [Initial     ] residual : 2.593833e-01, lambda : 4.210190e-01
# [Open3D DEBUG] [Iteration 00] residual : 1.023008e-01, valid edges : 1, time : 0.000 sec.
# [Open3D DEBUG] [Iteration 01] residual : 8.042373e-02, valid edges : 1, time : 0.000 sec.
# [Open3D DEBUG] [Iteration 02] residual : 8.037479e-02, valid edges : 1, time : 0.000 sec.
# [Open3D DEBUG] Current_residual - new_residual < 1.000000e-06 * current_residual
# [Open3D DEBUG] [GlobalOptimizationLM] total time : 0.000 sec.
# [Open3D DEBUG] [GlobalOptimizationLM] Optimizing PoseGraph having 3 nodes and 3 edges.
# [Open3D DEBUG] Line process weight : 1.785800
# [Open3D DEBUG] [Initial     ] residual : 8.037471e-02, lambda : 4.206641e-01
# [Open3D DEBUG] Current_residual - new_residual < 1.000000e-06 * current_residual
# [Open3D DEBUG] [GlobalOptimizationLM] total time : 0.000 sec.
# [Open3D DEBUG] CompensateReferencePoseGraphNode : reference : 0
# [[ 1.00000000e+00 -4.32780896e-20  1.08420217e-19  2.16840434e-19]
#  [-4.33045594e-20  1.00000000e+00  2.71050543e-20  2.16840434e-19]
#  [ 1.08420217e-19  2.71050543e-20  1.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# [[ 0.9997928   0.00207114  0.02025026  0.0133603 ]
#  [-0.00185469  0.99994102 -0.01070141 -0.02077439]
#  [-0.02027123  0.01066163  0.99973767 -0.00594348]
#  [ 0.          0.          0.          1.        ]]
# [[ 0.99973205  0.00323516 -0.02292096 -0.01198612]
#  [-0.00344401  0.99995286 -0.00907818 -0.02105771]
#  [ 0.02289051  0.00915468  0.99969606 -0.03206354]
#  [ 0.          0.          0.          1.        ]]
# [Open3D DEBUG] Add geometry and update bounding box to [(0.0772, -0.7010, -0.7349) - (1.4652, 0.8120, -0.4499)]
# [Open3D DEBUG] Add geometry and update bounding box to [(0.0772, -0.7302, -0.7349) - (1.7287, 0.8120, -0.4088)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-0.1628, -0.7388, -0.7449) - (1.7287, 0.8120, -0.4012)]
# [Open3D DEBUG] [Visualizer] Point size set to 4.00.
# [Open3D DEBUG] [Visualizer] Point size set to 3.00.
# [Open3D DEBUG] [Visualizer] Point size set to 2.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] Add geometry and update bounding box to [(0.0772, -0.7010, -0.7349) - (1.4652, 0.8120, -0.4499)]
# [Open3D DEBUG] Add geometry and update bounding box to [(0.0772, -0.7302, -0.7349) - (1.7287, 0.8120, -0.4088)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-0.1628, -0.7388, -0.7449) - (1.7287, 0.8120, -0.4012)]
# [Open3D DEBUG] [Visualizer] Point size set to 4.00.
# [Open3D DEBUG] [Visualizer] Point size set to 3.00.
# [Open3D DEBUG] [Visualizer] Point size set to 2.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] Pointcloud down sampled from 4643397 points to 166389 points.
# [Open3D DEBUG] Add geometry and update bounding box to [(-0.1618, -0.7378, -0.7443) - (1.7270, 0.8106, -0.4015)]
# [Open3D DEBUG] [Visualizer] Point size set to 4.00.
# [Open3D DEBUG] [Visualizer] Point size set to 3.00.
# [Open3D DEBUG] [Visualizer] Point size set to 2.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
